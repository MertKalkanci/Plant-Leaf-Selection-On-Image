# %% [markdown]
# # **Welcome**
#
# [Original Google Collab Notebook Link](https://colab.research.google.com/drive/1wDifY2AoJ8N4HlNrQ7QN9rTFWFmJjp7k?usp=sharing)
#
# Made By Mert Kalkancı for Akasu Plant Disease Detection Project
#
# [Github Page Link](https://github.com/MertKalkanci/Plant-Leaf-Selection-On-Image)
#
# [LICENSED UNDER MIT LICENSE](https://github.com/MertKalkanci/Plant-Leaf-Selection-On-Image/blob/main/LICENSE)
#
# Also it would be nice if you credit me :)

# %% [markdown]
# # **To Start Install PlantCV**
# (You need to restart runtime in Google Collab)

# %%
# !pip install --upgrade plantcv pillow
# Out:
# Requirement already satisfied: plantcv in /usr/local/lib/python3.10/dist-packages (3.14.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (10.0.0)
# Requirement already satisfied: matplotlib<3.6,>=1.5 in /usr/local/lib/python3.10/dist-packages (from plantcv) (3.5.3)
# Requirement already satisfied: numpy<1.23,>=1.11 in /usr/local/lib/python3.10/dist-packages (from plantcv) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from plantcv) (1.5.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from plantcv) (2.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from plantcv) (1.10.1)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.10/dist-packages (from plantcv) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from plantcv) (1.2.2)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.10/dist-packages (from plantcv) (0.10.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (from plantcv) (2022.12.1)
# Requirement already satisfied: dask-jobqueue in /usr/local/lib/python3.10/dist-packages (from plantcv) (0.8.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from plantcv) (4.7.0.72)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from plantcv) (0.13.5)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=1.5->plantcv) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=1.5->plantcv) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=1.5->plantcv) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=1.5->plantcv) (23.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=1.5->plantcv) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->plantcv) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19->plantcv) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19->plantcv) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19->plantcv) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19->plantcv) (1.4.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (8.1.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (2.2.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (2023.6.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask->plantcv) (0.12.0)
# Requirement already satisfied: distributed>=2022.02.0 in /usr/local/lib/python3.10/dist-packages (from dask-jobqueue->plantcv) (2022.12.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->plantcv) (2022.7.1)
# Requirement already satisfied: mizani>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from plotnine->plantcv) (0.8.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from plotnine->plantcv) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->plantcv) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->plantcv) (3.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.1.2)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.5)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (5.9.5)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.0.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (6.3.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.26.16)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (3.0.0)
# Requirement already satisfied: palettable in /usr/local/lib/python3.10/dist-packages (from mizani>=0.8.1->plotnine->plantcv) (3.3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->distributed>=2022.02.0->dask-jobqueue->plantcv) (2.1.3)

# %% [markdown]
# # **0. Import Necessary Libraries**

# %%
import sys, traceback
import cv2
import os
import re
import numpy as np
import argparse
import string
from matplotlib import pyplot as plt
from plantcv import plantcv as pcv
from PIL import Image

# %% [markdown]
# # **1. Configure Settings**

# %%
mask_type_is_b = True
treshold = 160
input_file = '/content/input_rasberry.png'
output_dir = '/content/output/'

output_image_size = [128,128]

# %% [markdown]
# # **2. Import Image**

# %%
pcv.params.debug="plot" #set debug mode
img, path, filename = pcv.readimage(input_file)


img_size = img.shape

print(img_size)

if np.average(img) < 50:
  pcv.fatal_error("Night Image")
else:
  pass
# Out:
# (285, 552, 3)

# %% [markdown]
#  # **3. Mask & Select Bottom Left Part Of Plant**

# %% [markdown]
# ###3.1 **Mask Image With LAB Channels**

# %%
if mask_type_is_b:
  mask, masked_img = pcv.threshold.custom_range(img=img, lower_thresh=[0,0,treshold],
                                              upper_thresh=[255,255,255], channel='LAB')
else:
  mask, masked_img = pcv.threshold.custom_range(img=img, lower_thresh=[treshold,0,0],
                                              upper_thresh=[255,255,255], channel='LAB')
masked = pcv.apply_mask(img=img, mask=mask, mask_color='white')

# %% [markdown]
# ###3.2 **Apply Roi & Select Bottom Right Part**

# %%
rois, roi_hierarchy = pcv.roi.circle(img, x=(img_size[1] - 50), y=(img_size[0] - 50),r=50)

# %%
id_objects, obj_hierarchy = pcv.find_objects(img=masked,mask=mask)

roi_objects, hierarchy, kept_mask, obj_area = pcv.roi_objects(img, rois, roi_hierarchy,
                                                              id_objects, obj_hierarchy, 'partial')

pcv.print_image(img=kept_mask, filename=f'{output_dir}mask.png')

# %% [markdown]
# # **4. Apply Watershred Segmentation**

# %%
analysis_images = pcv.watershed_segmentation(rgb_img=masked, mask=kept_mask, distance=15, label="")

height, width, channels = analysis_images.shape
analysis_images = analysis_images[0:height,0:int(width/2)]

pcv.print_image(img=analysis_images, filename=f'{output_dir}mask.png')
pcv.plot_image(analysis_images)

# %%
pcv.params.debug="None" #change debug mode to prevent every log

# %% [markdown]
# # **5. Function That Exports Leave With Threshold**

# %%
def try_to_extract_leaf_with_thresh(lower_thresh,upper_thresh):

  is_empty = True

  mask_thresh = cv2.inRange(analysis_images, lower_thresh, upper_thresh)

  # change all non-specified color to white
  result = analysis_images.copy()
  result[mask_thresh!=255] = (0, 0, 0)

  gray_mask = pcv.rgb2gray(rgb_img=result)
  masked_final = pcv.apply_mask(img=masked_img, mask=gray_mask, mask_color="black")

  list_y,list_x = [],[]

  for i in range(len(masked_final)):

    for j in range(len(masked_final[i])):

      if (masked_final[i][j] != [0,0,0]).any(): #check is there any color on masked_final to cut image and specify is that empty or not
        is_empty = False

        list_y.append(i)
        list_x.append(j)

  if is_empty:
    return 'EMPTY'

  else:
    list_y = np.array(list_y)
    list_x = np.array(list_x)

    y1 = np.amin(list_y)
    x1 = np.amin(list_x)
    y2 = np.max(list_y)
    x2 = np.max(list_x)

    height, width, channels = masked_final.shape

    output = cv2.resize(masked_final[y1:y2,x1:x2], output_image_size, interpolation= cv2.INTER_LINEAR)

    return output

# %% [markdown]
# # **6. Extraction Of All Leaves From Watershredded Mask Image**

# %% [markdown]
# ###6.1 A **Threshold Map Method 1 - Getting Colors & Threshing (Recommended)**

# %%
lower=np.empty([1,3])
upper=np.empty([1,3])
color_map=np.empty([1,3])

for i in range(len(analysis_images)):

  for j in range(len(analysis_images[i])):
      if (analysis_images[i][j] != [0,0,0]).any():

          #if len(color_map) > 0: # if not has any color never checks colors inside

          has_the_color = False

          for color in color_map: #check every color
              if (analysis_images[i][j] == color).all():
                      has_the_color = True

          if not has_the_color:
               color_map = np.append(color_map, [analysis_images[i][j]], axis=0)

          #else:
          #  print('first')
          #  color_map = np.append(color_map, [analysis_images[i][j]], axis=0)

for color in color_map:
  print(color)
  lower = np.append(lower, [[color[0], color[1], color[2]]], axis=0)
  upper = np.append(lower, [[color[0] + 1, color[1] + 1, color[2] + 1]], axis=0)
# Out:
# [256.   1. 192.]
# [255.   0.  40.]
# [255.   7.   0.]
# [255.  61.   0.]
# [255. 115.   0.]
# [255. 169.   0.]
# [255. 223.   0.]
# [232. 255.   0.]
# [183. 255.   0.]
# [129. 255.   0.]
# [ 75. 255.   0.]
# [ 21. 255.   0.]
# [  0. 255.  32.]
# [  0. 255.  86.]
# [  0. 255. 139.]
# [  0. 255. 241.]
# [  0. 159. 255.]
# [  0. 255. 188.]
# [  0. 213. 255.]
# [  0.   1. 255.]
# [  0. 105. 255.]
# [  0.  50. 255.]
# [ 52.   0. 255.]
# [106.   0. 255.]
# [255.   0. 240.]
# [161.   0. 255.]
# [215.   0. 255.]
# [255.   0. 191.]

# %% [markdown]
# ###6.1 B **Threshold Map Method 2 - Checking Every Color (Not Recommended but shown there as an alternative)**

# %%
lower=np.empty([1,3])
upper=np.empty([1,3])

#color_array = np.unique(analysis_images)

for r in range(0,12):

  for g in range(0,12):

    for b in range(0,12):
      lower = np.append(lower,[[r * 20,
                               g * 20,
                               b * 20]],
                         axis=0)
      upper = np.append(upper,[[(r+1) * 20 + 15,
                               (g+1) * 20 + 15,
                               (b+1) * 20 + 15]],
                        axis=0)

# %% [markdown]
# ###6.2 **Show Threshold Maps**

# %%
print(lower)
# Out:
# [[  0. 100. 200.]
#  [256.   1. 192.]
#  [255.   0.  40.]
#  [255.   7.   0.]
#  [255.  61.   0.]
#  [255. 115.   0.]
#  [255. 169.   0.]
#  [255. 223.   0.]
#  [232. 255.   0.]
#  [183. 255.   0.]
#  [129. 255.   0.]
#  [ 75. 255.   0.]
#  [ 21. 255.   0.]
#  [  0. 255.  32.]
#  [  0. 255.  86.]
#  [  0. 255. 139.]
#  [  0. 255. 241.]
#  [  0. 159. 255.]
#  [  0. 255. 188.]
#  [  0. 213. 255.]
#  [  0.   1. 255.]
#  [  0. 105. 255.]
#  [  0.  50. 255.]
#  [ 52.   0. 255.]
#  [106.   0. 255.]
#  [255.   0. 240.]
#  [161.   0. 255.]
#  [215.   0. 255.]
#  [255.   0. 191.]]

# %% [markdown]
# ###6.3 **Extracting Leaves With Threshold Map**#

# %%
leaves = np.empty([1,128,128,3])
for i in range(0,len(lower)):
  print(f'Number:{i+1}, Total:{len(lower)}')
  if try_to_extract_leaf_with_thresh(lower[i],upper[i]) != 'EMPTY':
    #pcv.plot_image(try_to_extract_leaf_with_thresh(lower[i],upper[i]))
    leaves = np.append(leaves,
                       [try_to_extract_leaf_with_thresh(lower[i],upper[i])],
                       axis=0)
# Out:
# Number:1, Total:29
# Number:2, Total:29
# Number:3, Total:29
# <ipython-input-19-94392adf5588>:4: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# Number:4, Total:29
# Number:5, Total:29
# Number:6, Total:29
# Number:7, Total:29
# Number:8, Total:29
# Number:9, Total:29
# Number:10, Total:29
# Number:11, Total:29
# Number:12, Total:29
# Number:13, Total:29
# Number:14, Total:29
# Number:15, Total:29
# Number:16, Total:29
# Number:17, Total:29
# Number:18, Total:29
# Number:19, Total:29
# Number:20, Total:29
# Number:21, Total:29
# Number:22, Total:29
# Number:23, Total:29
# Number:24, Total:29
# Number:25, Total:29
# Number:26, Total:29
# Number:27, Total:29
# Number:28, Total:29
# Number:29, Total:29

# %% [markdown]
# # **6. Saving Leave Files**

# %%
for i in range(0, len(leaves)):
  pcv.print_image(img=leaves[i], filename=f'{output_dir}OUTPUT_{i}.png')

# %% [markdown]
# # **7. Showing Leave Images**

# %%
fig = plt.figure(figsize=(10, 10))
columns = 3
rows = 3
for i in range(1, columns*rows+1):
    fig.add_subplot(rows, columns, i)
    rgb = cv2.cvtColor(cv2.imread(f'{output_dir}OUTPUT_{i}.png'), cv2.COLOR_BGR2RGB)# converting BGR to RGB
    plt.imshow(rgb/255)
plt.show()
